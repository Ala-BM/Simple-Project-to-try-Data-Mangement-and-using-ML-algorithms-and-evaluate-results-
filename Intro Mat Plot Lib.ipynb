# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot();

# %%
### 1st Method
fig=plt.figure()
ax=fig.add_subplot()
plt.show()

# %%
x=[1,5,6,7]
y=[77,8,55,11]
fig ,ax =plt.subplots()
ax.plot(x,y)

# %% [markdown]
# # Matplot lib lets goo

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

x=[1,2,3,4]
y=[11,22,33,44]

fig, ax=plt.subplots(figsize=(5,5))

ax.plot(x,y)

ax.set(title="Simple plot",
      xlabel="x-axis",
      ylabel="y-axis")
fig.savefig("yes.png")

# %%
x=np.linspace(0,10,100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
fig ,ax =plt.subplots()
ax.plot(x ,x**2)

# %%
fig ,ax =plt.subplots()
ax.scatter(x ,np.exp(x));

# %%
fig ,ax=plt.subplots()
ax.scatter(x,np.sin(x))

# %%
nut_prices={"Almond":10,
           "Peanut":8,
           "Cashew":12}
fig,ax=plt.subplots()

ax.bar(nut_prices.keys(),nut_prices.values())
ax.set(title="Prices",ylabel="Dollars",xlabel="Name");

# %%
fig ,ax=plt.subplots()
ax.barh(list(nut_prices.keys()),list(nut_prices.values()))
ax.set(title="H bar",
      xlabel="Prices ($)",
      ylabel="Names")
# Out:
# [Text(0.5, 1.0, 'H bar'), Text(0.5, 0, 'Prices ($)'), Text(0, 0.5, 'Names')]

# %%
x=np.random.randn(1000)
fig ,ax=plt.subplots()
ax.hist(x);

# %%
fig , ((ax1,ax2),(ax3,ax4))=plt.subplots(nrows=2,ncols=2,figsize=(10,5))
ax1.plot(x,x*2)
ax2.hist(x)
ax3.bar(x,x/6)
ax4.barh(x,np.sin(x))
# Out:
# <BarContainer object of 1000 artists>

# %%
fig, ax=plt.subplots(nrows=2,ncols=2,figsize=(10,5))

# %%
ts=pd.Series(np.random.randn(1000),index=pd.date_range("1/1/2021",periods=1000))
ts=-(ts.cumsum())
ts.plot()
# Out:
# <AxesSubplot: >

# %%
car_sales=pd.read_csv("49 - car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"]=car_sales["Price"].str.replace('[\$\,\.]','')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2964\4175487372.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"]=car_sales["Price"].str.replace('[\$\,\.]','')

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Price"]=car_sales["Price"].str[:-2]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["sales_date"]=pd.date_range("1/1/2022",periods=(len(car_sales)))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price sales_date
# 0  Toyota  White         150043      4   4000 2022-01-01
# 1   Honda    Red          87899      4   5000 2022-01-02
# 2  Toyota   Blue          32549      3   7000 2022-01-03
# 3     BMW  Black          11179      5  22000 2022-01-04
# 4  Nissan  White         213095      4   3500 2022-01-05
# 5  Toyota  Green          99213      4   4500 2022-01-06
# 6   Honda   Blue          45698      4   7500 2022-01-07
# 7   Honda   Blue          54738      4   7000 2022-01-08
# 8  Toyota  White          60000      4   6250 2022-01-09
# 9  Nissan  White          31600      4   9700 2022-01-10

# %%
car_sales["Total_Sales"]=car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price sales_date  Total_Sales
# 0  Toyota  White         150043      4   4000 2022-01-01         4000
# 1   Honda    Red          87899      4   5000 2022-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2022-01-03        16000
# 3     BMW  Black          11179      5  22000 2022-01-04        38000
# 4  Nissan  White         213095      4   3500 2022-01-05        41500
# 5  Toyota  Green          99213      4   4500 2022-01-06        46000
# 6   Honda   Blue          45698      4   7500 2022-01-07        53500
# 7   Honda   Blue          54738      4   7000 2022-01-08        60500
# 8  Toyota  White          60000      4   6250 2022-01-09        66750
# 9  Nissan  White          31600      4   9700 2022-01-10        76450

# %%
car_sales.plot(x="sales_date",y="Total_Sales");

# %%
car_sales["Price"]=car_sales["Price"].astype(int)
car_sales.plot(x="Odometer (KM)",y="Price",kind="barh");

# %%
x=np.random.rand(10,4)
df=pd.DataFrame(x,columns=["a","b","c","d"])
df
# Out:
#           a         b         c         d
# 0  0.150616  0.812517  0.548607  0.509614
# 1  0.427786  0.387694  0.848544  0.123237
# 2  0.990449  0.718377  0.597598  0.903845
# 3  0.386319  0.261337  0.128599  0.350111
# 4  0.443980  0.398810  0.941035  0.999433
# 5  0.287060  0.959700  0.375985  0.897460
# 6  0.042976  0.799324  0.682478  0.332927
# 7  0.773090  0.310565  0.525187  0.477994
# 8  0.183212  0.426533  0.585058  0.772808
# 9  0.317147  0.686224  0.248868  0.818850

# %%
df.plot.bar()
# Out:
# <AxesSubplot: >

# %%
car_sales.groupby(["Make"]).mean().plot(y="Odometer (KM)",kind="bar")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2964\1902122822.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   car_sales.groupby(["Make"]).mean().plot(y="Odometer (KM)",kind="bar")
# <AxesSubplot: xlabel='Make'>

# %%
car_sales["Odometer (KM)"].plot.hist(bins=10)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
heart_d=pd.read_csv("90 - heart-disease.csv")

# %%
heart_d
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
heart_d["age"].plot.hist(bins=10);

# %%
heart_d.plot.hist(figsize=(10,30),subplots=True);

# %%
over_50=heart_d[heart_d["age"]>50]
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
fig ,ax=plt.subplots(figsize=(10,6))
over_50.plot(kind="scatter",
            x="age",
            y="chol",
            c="target",
            ax=ax);
#ax.set_xlim([45,100])
# Out:
# (45.0, 100.0)

# %%
fig,ax=plt.subplots(figsize=(10,6))
scatter = ax.scatter(x=over_50["age"],
                    y=over_50["thalach"],
                    c=over_50["target"])
ax.set(title="Heart_D over 50",
      xlabel="age",
      ylabel="thalach",)
ax.legend(*scatter.legend_elements(),title="target")
ax.axhline(over_50["thalach"].mean(),linestyle="--")

# %%
fig ,(ax0,ax1)=plt.subplots(nrows=2,
                           ncols=1,
                           figsize=(10,12),
                           sharex=True)
scatter=ax0.scatter(x=over_50["age"],
                   y=over_50["chol"],
                   c=over_50["target"])
ax0.set(title="Age To Chol HD",

       ylabel="chol")
ax0.legend(*scatter.legend_elements(),title="Target")
ax0.axhline(over_50["chol"].mean(),linestyle=("--"))

scatter2=ax1.scatter(x=over_50["age"],
                   y=over_50["thalach"],
                   c=over_50["target"])
ax1.set(title="Age To thalach HD",
       xlabel="Age",
       ylabel="thalach")
ax1.legend(*scatter.legend_elements(),title="Target")
ax1.axhline(over_50["thalach"].mean(),linestyle=("--"))

fig.suptitle("Heart Desease Analysis",fontsize=16 ,fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Heart Desease Analysis')

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']
