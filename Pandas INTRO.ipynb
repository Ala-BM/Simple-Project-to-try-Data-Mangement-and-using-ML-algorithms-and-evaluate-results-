# %%
import pandas as pd

# %%
series=pd.Series(["bmw","toyota","Lambo"])

# %%
series
# Out:
# 0       bmw
# 1    toyota
# 2     Lambo
# dtype: object

# %%
colors=pd.Series(["red","blue","yellow"])

# %%
colors
# Out:
# 0       red
# 1      blue
# 2    yellow
# dtype: object

# %%
car_data=pd.DataFrame({"car":series,"colors":colors})

# %%
car_data
# Out:
#       car  colors
# 0     bmw     red
# 1  toyota    blue
# 2   Lambo  yellow

# %%
car_df=pd.read_csv("49 - car-sales.csv")

# %%
car_df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_df.to_csv("ExpCar.csv",index=False)

# %%
exp_car_df=pd.read_csv("ExpCar.csv")

# %%
exp_car_df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ### Desc Data

# %%
car_df.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_df.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_df["Odometer (KM)"].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 car_df["Odometer (KM)"].mean()
#
# NameError: name 'car_df' is not defined

# %%
car_df.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
animal=pd.Series(["Fox","Rat","Cat","Robin"],  index=[2 , 5, 4, 8])

# %%
animal
# Out:
# 2      Fox
# 5      Rat
# 4      Cat
# 8    Robin
# dtype: object

# %%
animal.iloc[3]
# Out:
# 'Robin'

# %%
car_df[car_df["Make"]=="BMW"]
# Out:
#   Make Colour  Odometer (KM)  Doors       Price
# 3  BMW  Black          11179      5  $22,000.00

# %%
pd.crosstab(car_df["Make"],car_df["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_df
# Out:
#      Make Colour  Odometer (KM)  Doors     Price
# 0  Toyota  White         150043      4   40000.0
# 1   Honda    Red          87899      4   50000.0
# 2  Toyota   Blue          32549      3   70000.0
# 3     BMW  Black          11179      5  220000.0
# 4  Nissan  White         213095      4   35000.0
# 5  Toyota  Green          99213      4   45000.0
# 6   Honda   Blue          45698      4   75000.0
# 7   Honda   Blue          54738      4   70000.0
# 8  Toyota  White          60000      4   62500.0
# 9  Nissan  White          31600      4   97000.0

# %%
car_df["Price"].hist()
# Out:
# <AxesSubplot: >

# %%
car_df.groupby(["Make"]).mean()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6480\2611807311.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   car_df.groupby(["Make"]).mean()
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %% [markdown]
# ### ManpuData

# %%
car_missd_df=pd.read_csv("54 - car-sales-missing-data.csv")

# %%
car_missd_df["Odometer"].fillna(car_missd_df["Odometer"].mean(),inplace=True)

# %%
car_missd_df
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_missd_df.dropna(inplace=True)

# %%
car_missd_df
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_missd_df.to_csv("car_missed_droped.csv")

# %%
seats_c=pd.Series([5,5,5,5,5])
car_df["Seats"]=seats_c
car_df
# Out:
#      Make Colour  Odometer (KM)  Doors     Price  Seats
# 0  Toyota  White         150043      4   40000.0    5.0
# 1   Honda    Red          87899      4   50000.0    5.0
# 2  Toyota   Blue          32549      3   70000.0    5.0
# 3     BMW  Black          11179      5  220000.0    5.0
# 4  Nissan  White         213095      4   35000.0    5.0
# 5  Toyota  Green          99213      4   45000.0    NaN
# 6   Honda   Blue          45698      4   75000.0    NaN
# 7   Honda   Blue          54738      4   70000.0    NaN
# 8  Toyota  White          60000      4   62500.0    NaN
# 9  Nissan  White          31600      4   97000.0    NaN

# %%
car_df["Seats"].fillna(5,inplace=True)

# %%
car_df
# Out:
#      Make Colour  Odometer (KM)  Doors     Price  Seats
# 0  Toyota  White         150043      4   40000.0    5.0
# 1   Honda    Red          87899      4   50000.0    5.0
# 2  Toyota   Blue          32549      3   70000.0    5.0
# 3     BMW  Black          11179      5  220000.0    5.0
# 4  Nissan  White         213095      4   35000.0    5.0
# 5  Toyota  Green          99213      4   45000.0    5.0
# 6   Honda   Blue          45698      4   75000.0    5.0
# 7   Honda   Blue          54738      4   70000.0    5.0
# 8  Toyota  White          60000      4   62500.0    5.0
# 9  Nissan  White          31600      4   97000.0    5.0

# %%
car_df["Price"]=car_df["Price"]/10

# %%
car_df
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  Toyota  White         150043      4   4000.0    5.0
# 1   Honda    Red          87899      4   5000.0    5.0
# 2  Toyota   Blue          32549      3   7000.0    5.0
# 3     BMW  Black          11179      5  22000.0    5.0
# 4  Nissan  White         213095      4   3500.0    5.0
# 5  Toyota  Green          99213      4   4500.0    5.0
# 6   Honda   Blue          45698      4   7500.0    5.0
# 7   Honda   Blue          54738      4   7000.0    5.0
# 8  Toyota  White          60000      4   6250.0    5.0
# 9  Nissan  White          31600      4   9700.0    5.0

# %%
fuel_e=[7.5,8.9,5.2,4.6,7.8,4.6,6.5,3.2,1.2,7.7]
car_df["Fulel Per 100Km"]=fuel_e

# %%
car_df
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fulel Per 100Km
# 0  Toyota  White         150043      4   4000.0    5.0              7.5
# 1   Honda    Red          87899      4   5000.0    5.0              8.9
# 2  Toyota   Blue          32549      3   7000.0    5.0              5.2
# 3     BMW  Black          11179      5  22000.0    5.0              4.6
# 4  Nissan  White         213095      4   3500.0    5.0              7.8
# 5  Toyota  Green          99213      4   4500.0    5.0              4.6
# 6   Honda   Blue          45698      4   7500.0    5.0              6.5
# 7   Honda   Blue          54738      4   7000.0    5.0              3.2
# 8  Toyota  White          60000      4   6250.0    5.0              1.2
# 9  Nissan  White          31600      4   9700.0    5.0              7.7

# %%
car_df["Total Fuel (L)"]=car_df["Odometer (KM)"]/100*car_df["Fulel Per 100Km"]

# %%
car_df
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fulel Per 100Km  \
# 0  Toyota  White         150043      4   4000.0    5.0              7.5
# 1   Honda    Red          87899      4   5000.0    5.0              8.9
# 2  Toyota   Blue          32549      3   7000.0    5.0              5.2
# 3     BMW  Black          11179      5  22000.0    5.0              4.6
# 4  Nissan  White         213095      4   3500.0    5.0              7.8
# 5  Toyota  Green          99213      4   4500.0    5.0              4.6
# 6   Honda   Blue          45698      4   7500.0    5.0              6.5
# 7   Honda   Blue          54738      4   7000.0    5.0              3.2
# 8  Toyota  White          60000      4   6250.0    5.0              1.2
# 9  Nissan  White          31600      4   9700.0    5.0              7.7
#
#    Fuel used In 100km
# 0           11253.225
# 1            7823.011
# 2            1692.548
# 3             514.234
# 4           16621.410
# 5            4563.798
# ...

# %%
car_df["N of Wheels"]=4

# %%
car_df
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fulel Per 100Km  \
# 0  Toyota  White         150043      4   4000.0    5.0              7.5
# 1   Honda    Red          87899      4   5000.0    5.0              8.9
# 2  Toyota   Blue          32549      3   7000.0    5.0              5.2
# 3     BMW  Black          11179      5  22000.0    5.0              4.6
# 4  Nissan  White         213095      4   3500.0    5.0              7.8
# 5  Toyota  Green          99213      4   4500.0    5.0              4.6
# 6   Honda   Blue          45698      4   7500.0    5.0              6.5
# 7   Honda   Blue          54738      4   7000.0    5.0              3.2
# 8  Toyota  White          60000      4   6250.0    5.0              1.2
# 9  Nissan  White          31600      4   9700.0    5.0              7.7
#
#    Fuel used In 100km  N of Wheels  Fuel used In 100km (L)
# 0           11253.225            4               11253.225
# ...

# %%
car_df.drop("Fuel used In 100km (L)",axis=1,inplace=True)

# %%
car_df
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fulel Per 100Km  \
# 0  Toyota  White         150043      4   4000.0    5.0              7.5
# 1   Honda    Red          87899      4   5000.0    5.0              8.9
# 2  Toyota   Blue          32549      3   7000.0    5.0              5.2
# 3     BMW  Black          11179      5  22000.0    5.0              4.6
# 4  Nissan  White         213095      4   3500.0    5.0              7.8
# 5  Toyota  Green          99213      4   4500.0    5.0              4.6
# 6   Honda   Blue          45698      4   7500.0    5.0              6.5
# 7   Honda   Blue          54738      4   7000.0    5.0              3.2
# 8  Toyota  White          60000      4   6250.0    5.0              1.2
# 9  Nissan  White          31600      4   9700.0    5.0              7.7
#
#    N of Wheels  Total Fuel (L)
# 0            4       11253.225
# 1            4        7823.011
# 2            4        1692.548
# 3            4         514.234
# ...

# %%
import random
car_df["Bass"]=random.choice(["Good","Mid","Bad"])
car_df
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fulel Per 100Km  \
# 0  Toyota  White         150043      4   4000.0    5.0              7.5
# 1   Honda    Red          87899      4   5000.0    5.0              8.9
# 2  Toyota   Blue          32549      3   7000.0    5.0              5.2
# 3     BMW  Black          11179      5  22000.0    5.0              4.6
# 4  Nissan  White         213095      4   3500.0    5.0              7.8
# 5  Toyota  Green          99213      4   4500.0    5.0              4.6
# 6   Honda   Blue          45698      4   7500.0    5.0              6.5
# 7   Honda   Blue          54738      4   7000.0    5.0              3.2
# 8  Toyota  White          60000      4   6250.0    5.0              1.2
# 9  Nissan  White          31600      4   9700.0    5.0              7.7
#
#    N of Wheels  Total Fuel (L)  Bass
# 0            4       11253.225  Good
# 1            4        7823.011  Good
# 2            4        1692.548  Good
# ...

# %%
car_df.sample(frac=1)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fulel Per 100Km  \
# 0  Toyota  White         150043      4   4000.0    5.0              7.5
# 7   Honda   Blue          54738      4   7000.0    5.0              3.2
# 1   Honda    Red          87899      4   5000.0    5.0              8.9
# 6   Honda   Blue          45698      4   7500.0    5.0              6.5
# 4  Nissan  White         213095      4   3500.0    5.0              7.8
# 8  Toyota  White          60000      4   6250.0    5.0              1.2
# 9  Nissan  White          31600      4   9700.0    5.0              7.7
# 5  Toyota  Green          99213      4   4500.0    5.0              4.6
# 2  Toyota   Blue          32549      3   7000.0    5.0              5.2
# 3     BMW  Black          11179      5  22000.0    5.0              4.6
#
#    N of Wheels  Total Fuel (L)  Bass
# 0            4       11253.225  Good
# 7            4        1751.616  Good
# 1            4        7823.011  Good
# ...

# %%
car_shuffle=car_df.sample(frac=1)

# %%
car_shuffle
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fulel Per 100Km  \
# 0  Toyota  White         150043      4   4000.0    5.0              7.5
# 9  Nissan  White          31600      4   9700.0    5.0              7.7
# 2  Toyota   Blue          32549      3   7000.0    5.0              5.2
# 6   Honda   Blue          45698      4   7500.0    5.0              6.5
# 8  Toyota  White          60000      4   6250.0    5.0              1.2
# 3     BMW  Black          11179      5  22000.0    5.0              4.6
# 5  Toyota  Green          99213      4   4500.0    5.0              4.6
# 4  Nissan  White         213095      4   3500.0    5.0              7.8
# 7   Honda   Blue          54738      4   7000.0    5.0              3.2
# 1   Honda    Red          87899      4   5000.0    5.0              8.9
#
#    N of Wheels  Total Fuel (L)  Bass
# 0            4       11253.225  Good
# 9            4        2433.200  Good
# 2            4        1692.548  Good
# ...

# %%
car_shuffle.reset_index(drop=True,inplace=True)
car_shuffle
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fulel Per 100Km  \
# 0  Toyota  White         150043      4   4000.0    5.0              7.5
# 1  Nissan  White          31600      4   9700.0    5.0              7.7
# 2  Toyota   Blue          32549      3   7000.0    5.0              5.2
# 3   Honda   Blue          45698      4   7500.0    5.0              6.5
# 4  Toyota  White          60000      4   6250.0    5.0              1.2
# 5     BMW  Black          11179      5  22000.0    5.0              4.6
# 6  Toyota  Green          99213      4   4500.0    5.0              4.6
# 7  Nissan  White         213095      4   3500.0    5.0              7.8
# 8   Honda   Blue          54738      4   7000.0    5.0              3.2
# 9   Honda    Red          87899      4   5000.0    5.0              8.9
#
#    N of Wheels  Total Fuel (L)  Bass
# 0            4       11253.225  Good
# 1            4        2433.200  Good
# 2            4        1692.548  Good
# ...

# %%
car_shuffle["Odometer (KM)"]=car_shuffle["Odometer (KM)"].apply(lambda x:x/1.6)

# %%
car_shuffle
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fulel Per 100Km  \
# 0  Toyota  White      93776.875      4   4000.0    5.0              7.5
# 1  Nissan  White      19750.000      4   9700.0    5.0              7.7
# 2  Toyota   Blue      20343.125      3   7000.0    5.0              5.2
# 3   Honda   Blue      28561.250      4   7500.0    5.0              6.5
# 4  Toyota  White      37500.000      4   6250.0    5.0              1.2
# 5     BMW  Black       6986.875      5  22000.0    5.0              4.6
# 6  Toyota  Green      62008.125      4   4500.0    5.0              4.6
# 7  Nissan  White     133184.375      4   3500.0    5.0              7.8
# 8   Honda   Blue      34211.250      4   7000.0    5.0              3.2
# 9   Honda    Red      54936.875      4   5000.0    5.0              8.9
#
#    N of Wheels  Total Fuel (L)  Bass
# 0            4       11253.225  Good
# 1            4        2433.200  Good
# 2            4        1692.548  Good
# ...
